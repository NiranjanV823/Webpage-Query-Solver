# %%
# !pip install llama-index llama-index-llms-huggingface llama-index-embeddings-huggingface transformers accelerate bitsandbytes llama-index-readers-web
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 104.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.core import Settings
from IPython.display import Markdown, display
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
URL = "https://laravel.com/docs/11.x"

# %%
import torch
from transformers import BitsAndBytesConfig
from llama_index.llms.huggingface import HuggingFaceLLM

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

# %%
Settings.llm = HuggingFaceLLM(
    model_name="berkeley-nest/Starling-LM-7B-alpha",
    tokenizer_name="berkeley-nest/Starling-LM-7B-alpha",
    context_window=3900,
    max_new_tokens=256,
    model_kwargs={"quantization_config": quantization_config},
    generate_kwargs={"temperature": 0.8, "do_sample": True},
    device_map="auto",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ...

# %%
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from llama_index.core import VectorStoreIndex

# %%
Settings.chunk_size = 512
Settings.chunk_overlap = 50

# %%
from llama_index.core import download_loader
BeautifulSoupWebReader = download_loader("BeautifulSoupWebReader")
loader = BeautifulSoupWebReader()
documents = loader.load_data(urls=[URL])
# Out:
# <ipython-input-12-65e3d4792905>:2: DeprecationWarning: Call to deprecated function (or staticmethod) download_loader. (`download_loader()` is deprecated. Please install tool using pip install directly instead.)
#   BeautifulSoupWebReader = download_loader("BeautifulSoupWebReader")

# %%
vector_index = VectorStoreIndex.from_documents(
    documents,
)

# %%
query_engine = vector_index.as_query_engine(similarity_top_k=3)

# %%
text=input("Input your query here about Laravel: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here about Laravel: is laravel a framework or library
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# Laravel is a full-stack framework. It is stated in the Laravel Documentation that Laravel may serve as a full-stack framework that includes routing, views, API backends, and more.
# It is also mentioned that Laravel combines the best packages in the PHP ecosystem to offer the most robust and developer-friendly framework available, implying it is a framework.
#
# In addition, Laravel the Full Stack Framework section in the Laravel documentation clearly states that Laravel may serve as a full stack framework, which includes routing, views, API backends, and more.
#
# Finally, Laravel is described as a web application framework with expressive, elegant syntax, indicating that Laravel is a framework.
#
# Therefore, Laravel is a framework rather than a library.
#
# Explanation:
#
# ...

# %%
text=input("Input your query here about Laravel: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here about Laravel: tell me about paris olympic 2024
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# Paris is going to host the 2024 Summer Olympic Games, this is the Third time that Paris hosts the Games, previously it was in the years 1900 and 1924. The sporting event is scheduled to take place from 26 July to 11 August 2024
# The Olympic Games, also known as the Games of the XXXIII Olympiad, are scheduled to take place in Paris, France, from 26 July to 11 August 2024. They will be the third time that Paris has hosted the Summer Olympic Games, previously hosting the Games in 1900 and 1924.
#
# ...

# %%
text=input("Input your query here about Laravel: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here about Laravel: who is Daenerys Targaryen
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# In Game of Thrones, Daenerys Targaryen is a character, known as "the Dragon Queen". Daenerys is one of the main characters of the television series and is portrayed by Emilia Clarke in the HBO adaptation of the series, based on George R. R. Martin's A Song of Ice and Fire novels.
#
# Here's a brief overview of her background and storyline:
#
# - Daenerys Targaryen is the youngest daughter of Aerys II Targaryen, the Mad King, and his wife, Rhaella Targaryen. She was born in the Red Keep in King's Landing.
# - At a young age, Daenerys, her brother Viserys, and her mother were exiled by the ruling council and fled to Dragonstone, where they were taken care of by Ser Willem Darry.
# - After the betrayal and murder of Ser Willem Darry, Daenerys, Viserys, and their remaining retinue traveled to Pentos, where they lived for several years in exile.
# ...

# %%
URL = "https://en.wikipedia.org/wiki/Daenerys_Targaryen"

# %%
BeautifulSoupWebReader = download_loader("BeautifulSoupWebReader")
loader = BeautifulSoupWebReader()
documents = loader.load_data(urls=[URL])
# Out:
# <ipython-input-20-b52d7c608d61>:1: DeprecationWarning: Call to deprecated function (or staticmethod) download_loader. (`download_loader()` is deprecated. Please install tool using pip install directly instead.)
#   BeautifulSoupWebReader = download_loader("BeautifulSoupWebReader")

# %%
vector_index = VectorStoreIndex.from_documents(
    documents,
)

# %%
query_engine = vector_index.as_query_engine(similarity_top_k=3)

# %%
text=input("Input your query here about Daenerys Targaryen: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here about Daenerys Targaryen: who is daenerys targaryen
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# Daenerys Targaryen is a character from A Song of Ice and Fire, a popular book series and television show. She's a strong, confident, and courageous character who is the heir of the Targaryen dynasty. Daenerys was born during a great storm, earning her the nickname "Stormborn." Her father and eldest brother, Rhaegar and Viserys, were killed during Robert's rebellion. Daenerys and her brother were whisked away to Braavos by Ser Willem Darry until she was five years old. By the beginning of the series, Daenerys and her brother had been a guest of Illyrio Mopatis in Pentos for half a year. Daenerys eventually becomes a powerful, relentless, but self-critical ruler. In the television adaptation of Game of Thrones, she is portrayed by Emilia Clarke, who has received several award nominations for her performance.
#
# ...

# %%
text=input("Input your query here about Daenerys Targaryen: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here about Daenerys Targaryen: who is daenerys targaryen
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# Daenerys Targaryen is the daughter of King Aerys II Targaryen (also referred to as "The Mad King") and his sister-wife Queen Rhaella, and is one of the last survivors of House Targaryen.
#
# In the television adaptation of Game of Thrones, she is portrayed by British actress Emilia Clarke.
#
# ...

# %%
text=input("Input your query here from the model: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here from the model: tell me about kolkate rape case
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# In 2013, two Indian men were arrested in Kolkata, India, for the gang rape and murder of a 5-year-old girl. The men were charged and convicted, and were sentenced to life imprisonment.
#
# Here are some external information sources related to this topic:
#
# URL: http://www.thestatesman.com/kolkata-news/kolkata-rape-case-trial-from-horror-to-parody-1425873149.html
# Archived from the original on October 22, 2016. Retrieved October 18, 2020.
#
# URL: https://indianexpress.com/article/cities/kolkata/kolkata-rape-case-the-laughing-judge-and-other-trials-from-horror-to-parody-4007552/
# Archived from the original on October 22, 2016. Retrieved October 18, 2020.
#
# The Kolkata rape case

# %%
text=input("Input your query here from the model: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here from the model: tell me about kolkate rape case 2024
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# The Kolkata rape case of 2024 refers to a highly publicized and politically sensitive case involving the alleged rape of a young girl in Kolkata, India. The case gained nationwide attention and sparked widespread protests and demonstrations across the country. The case was ultimately dismissed due to lack of evidence, but the incident continues to have a profound impact on the public discourse on sexual assault and the handling of such cases in India.
#
# The alleged victim, a young girl, claimed she was raped by a man in Kolkata in 2024. The case gained significant media attention, as it was perceived as a test of the country’s commitment to addressing and combating sexual assault and violence against women.
#
# ...

# %%
text=input("Input your query here from the model: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here from the model: how many gold medal did usa won in 2024 paris olympic
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# The USA (United States of America) has not competed in the 2024 Paris Olympic yet, as it was held in Paris, France. It would not have been possible for the United States' athletes to have won a gold medal in 2024 because the games had not yet taken place.
#
# The USA (United States of America) has not competed in the 2026 Milan Olympic yet, as it will be held in Milan, Italy. It is not possible for the United States' athletes to have won a gold medal in 2026 because the games have not yet taken place.
#
# The USA (United States of America) has competed in the 2020 Tokyo Olympic, as it was held in Tokyo, Japan. The United States' athletes have won a total of 39 gold medals during the 2020 Tokyo Olympic.
#
# In the 2020 Tokyo Olympic, the United States' athletes have won a total of 39 gold medals.
#
# ...

# %%
URL = 'https://www.ndtv.com/india-news/kolkata-doctor-rape-murder-rg-kar-medical-college-and-hospital-150-mg-semen-in-kolkata-doctors-body-suspect-gangrape-parents-to-court-6335277'

# %%
BeautifulSoupWebReader = download_loader("BeautifulSoupWebReader")
loader = BeautifulSoupWebReader()
documents = loader.load_data(urls=[URL])
# Out:
# <ipython-input-30-b52d7c608d61>:1: DeprecationWarning: Call to deprecated function (or staticmethod) download_loader. (`download_loader()` is deprecated. Please install tool using pip install directly instead.)
#   BeautifulSoupWebReader = download_loader("BeautifulSoupWebReader")

# %%
vector_index = VectorStoreIndex.from_documents(
    documents,
)

# %%
query_engine = vector_index.as_query_engine(similarity_top_k=3)

# %%
text=input("Input your query here from model: ")
response = query_engine.query(text)
print(response)
# Out:
# Input your query here from model: tell me about kolkata rape case 2024
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# ...
